# %%
import pandas as pd
import matplotlib.pyplot as plt

datafile = "/Users/mattelms/Documents/School/CCM_Computing_Entry_Survey_Cleaned.csv"
df=pd.read_csv(datafile)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'course_enrolled', 'openhouse',
#        'instantdecisionday', 'onCampusInfoSession', 'virtualInfoSession',
#        'womenWhoDare', 'regionalCollegeFair', 'HS_Sharetime', 'challenger',
#        'CSIPPP', 'HSInfoSession', 'HSCampusVisit', 'IndivCampusVisit',
#        'workforceDev', 'corporateTraining', 'teenArtsFest', 'CCMSummerCamp',
#        'hourOfCode', 'computingClass_HS', 'computerClub_HS', 'computerComp',
#        'degree_program', 'Gender', 'race', 'Age '],
#       dtype='object')

# %%
df_clean = pd.DataFrame(df)

# %%
df_clean.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'course_enrolled', 'openhouse',
#        'instantdecisionday', 'onCampusInfoSession', 'virtualInfoSession',
#        'womenWhoDare', 'regionalCollegeFair', 'HS_Sharetime', 'challenger',
#        'CSIPPP', 'HSInfoSession', 'HSCampusVisit', 'IndivCampusVisit',
#        'workforceDev', 'corporateTraining', 'teenArtsFest', 'CCMSummerCamp',
#        'hourOfCode', 'computingClass_HS', 'computerClub_HS', 'computerComp',
#        'degree_program', 'Gender', 'race', 'Age '],
#       dtype='object')

# %%
df_clean = df_clean.rename(columns={'Age ':'Age','Race/ethnicity':'race','Which course are you enrolled in?': 'course_enrolled',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]': 'openhouse',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]':'instantdecisionday',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]':'onCampusInfoSession',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]':'virtualInfoSession',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]':'womenWhoDare',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]':'regionalCollegeFair',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]':'HS_Sharetime',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]':'challenger',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]':'CSIPPP',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]':'HSInfoSession',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]':'HSCampusVisit',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]':'IndivCampusVisit',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]':'workforceDev',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]':'corporateTraining',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]':'teenArtsFest',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]':'CCMSummerCamp',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]':'hourOfCode',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]': 'computingClass_HS',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]':'computerClub_HS',
       'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]':'computerComp',
       'What degree program are you currently enrolled in?':'degree_program',})

# %%
df_clean
# Out:
#      Unnamed: 0                   Timestamp
# 0             0  2022/09/26 12:13:34 PM EST  \
# 1             1   2022/09/26 1:36:22 PM EST
# 2             2   2022/09/26 1:37:38 PM EST
# 3             3   2022/09/26 1:39:43 PM EST
# 4             4   2022/09/26 1:40:07 PM EST
# ..          ...                         ...
# 213         213   2022/10/21 4:19:00 PM EST
# 214         214  2022/10/24 11:25:45 AM EST
# 215         215   2022/10/25 2:00:22 PM EST
# 216         216   2022/11/22 9:14:03 PM EST
# 217         217   2022/12/12 2:48:09 PM EST
#
#                                   course_enrolled openhouse
# 0                      CMP 128 Computer Science I       Yes  \
# 1                                           Blank        No
# 2                      CMP 128 Computer Science I        No
# 3                      CMP 128 Computer Science I       Yes
# 4                      CMP 128 Computer Science I        No
# ..                                            ...       ...
# ...

# %%
df_clean['race'] = df_clean.race.str.replace(r'(^.*;.*$)', 'Multi-racial', regex=True)
df_clean
# Out:
#      Unnamed: 0                   Timestamp
# 0             0  2022/09/26 12:13:34 PM EST  \
# 1             1   2022/09/26 1:36:22 PM EST
# 2             2   2022/09/26 1:37:38 PM EST
# 3             3   2022/09/26 1:39:43 PM EST
# 4             4   2022/09/26 1:40:07 PM EST
# ..          ...                         ...
# 213         213   2022/10/21 4:19:00 PM EST
# 214         214  2022/10/24 11:25:45 AM EST
# 215         215   2022/10/25 2:00:22 PM EST
# 216         216   2022/11/22 9:14:03 PM EST
# 217         217   2022/12/12 2:48:09 PM EST
#
#                                   course_enrolled openhouse
# 0                      CMP 128 Computer Science I       Yes  \
# 1                                           Blank        No
# 2                      CMP 128 Computer Science I        No
# 3                      CMP 128 Computer Science I       Yes
# 4                      CMP 128 Computer Science I        No
# ..                                            ...       ...
# ...

# %%
df_clean['race'].value_counts()
# Out:
# race
# White/Caucasian                                  92
# Hispanic or Latino                               44
# Asian                                            32
# Multi-racial                                     30
# Choose not to reply                              12
# Black/African American                            4
# Multi-Racial                                      3
# American Indian/Native American/Alaska Native     1
# Name: count, dtype: int64

# %%
cleaned_df = '/Users/mattelms/Documents/School/CCM_Computing_Entry_Survey_Cleaned_2.csv'
df_clean.to_csv(cleaned_df)

# %%
df_clean.groupby(['degree_program']).count()
# Out:
#                                                     Unnamed: 0  Timestamp
# degree_program
# Academy Student                                              1          1  \
# Bio                                                          1          1
# Business                                                     1          1
# Business Admin                                               1          1
# Business Administration                                      2          2
# Business Administration                                      2          2
# Business Professional                                        1          1
# Business and Marketing                                       1          1
# CIS Game Development Option                                  9          9
# Challenger Program                                           4          4
# Changed to Business                                          1          1
# ...

# %%
df_race = df_clean.groupby('race').size().reset_index(name='count')

df_race.plot(x='race', y='count', kind='bar')
plt.title('Racial Breakdown of Students responding to Survey')
plt.xlabel('Race')
plt.ylabel('Count')
plt.show()

# %%
df_race = df_clean.groupby('race').size().reset_index(name='count')

plt.pie(df_race['count'], autopct='%1.1f%%',labels=df_race.race,pctdistance=.8)
plt.title("Racial Breakdown of Students responding to Survey")
# Out:
# Text(0.5, 1.0, 'Racial Breakdown of Students responding to Survey')

# %%
df_gender = df_clean.groupby('Gender').size().reset_index(name='count')

plt.pie(df_gender['count'], autopct='%1.1f%%',labels=df_gender.Gender,pctdistance=0.8,textprops={'fontsize': 10}, explode=[0.1,0.1,0.2,0.1,0.1])
plt.title("Gender Breakdown of Students responding to Survey")
# Out:
# Text(0.5, 1.0, 'Gender Breakdown of Students responding to Survey')

# %%
df_age = df_clean.groupby('Age').size().reset_index(name='count')

plt.pie(df_age['count'], autopct='%1.1f%%',labels=df_age.Age,pctdistance=.8, textprops={'fontsize': 10})
plt.title("Age Breakdown of Students responding to Survey")
# Out:
# Text(0.5, 1.0, 'Age Breakdown of Students responding to Survey')

# %%
df_course = df_clean.groupby('course_enrolled').size().reset_index(name='count')

df_course.plot(x='course_enrolled', y='count', kind='bar')
plt.title('Course Breakdown of Students responding to Survey')
plt.xlabel('Courses')
plt.ylabel('Number')
plt.show()

# %%
age_mask = (df_clean['Age'] == '21-24') | (df_clean['Age'] == '19-20') | (df_clean['Age'] == '18 and younger')
race_mask = df_clean['race'] == 'White/Caucasian'
gender_mask = df_clean['Gender'] == 'Man'
filtered_df = df_clean[age_mask & race_mask & gender_mask]
white_male_25 = filtered_df.groupby('course_enrolled').size().reset_index(name='count')
white_male_25
# Out:
#                                 course_enrolled  count
# 0                    CMP 128 Computer Science I     48
# 1                           CMP 130 Intro to IT      3
# 2  CMP 131 Fundamentals of Programming (Python)      8
# 3            CMP 239 Internet & Web Page Design      5

# %%
plt.pie(white_male_25['count'], autopct='%1.1f%%',labels=white_male_25.course_enrolled,pctdistance=.8, textprops={'fontsize': 10})
plt.title("Percentage of Students in IT related Courses that are Caucasian Males Aged < 25")
# Out:
# Text(0.5, 1.0, 'Percentage of Students in IT related Courses that are Caucasian Males Aged > 25')

# %%
wm25_program = filtered_df.groupby('degree_program').size().reset_index(name='count')
wm25_program
# Out:
#                                      degree_program  count
# 0                           Business Administration      1
# 1                       CIS Game Development Option      3
# 2                                Challenger Program      1
# 3                                  Computer Science     21
# 4                          Digital Media Technology      1
# 5                            Information Technology     17
# 6                                      Liberal arts      1
# 7                                       Mathematics      1
# 8                            Mechanical engineering      5
# 9                                  Music Recording       1
# 10                           Share time engineering      1
# 11                           ShareTime CSIP Program      4
# 12  Technical Studies, Applied Associate of Science      1
# 13                                        Undecided      6

# %%
plt.pie(wm25_program['count'], autopct='%1.1f%%',labels=wm25_program.degree_program,pctdistance=.8, textprops={'fontsize': 5})
plt.title("What Degree Programs are Caucasian Males Aged < 25 enrolled in at CCM")
# Out:
# Text(0.5, 1.0, 'What Degree Programs are Caucasian Males Aged < 25 enrolled in at CCM')

# %%
age_mask1 = (df_clean['Age'] == '21-24') | (df_clean['Age'] == '19-20') | (df_clean['Age'] == '18 and younger')
race_mask1 = df_clean['race'] != 'White/Caucasian'
gender_mask1 = (df_clean['Gender'] != 'Man')
filtered_df_no_wm = df_clean[age_mask1 & race_mask1 & gender_mask1]
nonWM_25 = filtered_df_no_wm.groupby('course_enrolled').size().reset_index(name='count')
nonWM_25
# Out:
#                                 course_enrolled  count
# 0                    CMP 128 Computer Science I     20
# 1                           CMP 130 Intro to IT      1
# 2  CMP 131 Fundamentals of Programming (Python)      6
# 3            CMP 239 Internet & Web Page Design      5

# %%
plt.pie(nonWM_25['count'], autopct='%1.1f%%',labels=nonWM_25.course_enrolled,pctdistance=.8, textprops={'fontsize': 10})
plt.title("Percentage of Students who are NOT Caucasian Males, aged < 25 in IT related Courses")
# Out:
# Text(0.5, 1.0, 'Percentage of Students who are NOT Caucasian Males, aged > 25 in IT related Courses')

# %%
non_wm25_program = filtered_df_no_wm.groupby('degree_program').size().reset_index(name='count')
non_wm25_program
# Out:
#                                 degree_program  count
# 0                              Academy Student      1
# 1                     Business Administration       2
# 2                      Business and Marketing       1
# 3                  CIS Game Development Option      1
# 4                           Challenger Program      1
# 5                             Computer Science     15
# 6    Data Analytics Certificate of Achievement      1
# 7                      Electronics Engineering      1
# 8                       Information Technology      4
# 9                       Mechanical engineering      1
# 10                      ShareTime CSIP Program      2
# 11  Web Development Certificate of Achievement      1
# 12                                        edam      1

# %%
plt.pie(non_wm25_program['count'], autopct='%1.1f%%',labels=non_wm25_program.degree_program,pctdistance=.8, textprops={'fontsize': 8})
plt.title("What Degree Programs are students who are Aged < 25 but NOT Caucasian Males enrolled in at CCM")
# Out:
# Text(0.5, 1.0, 'What Degree Programs are students who are Aged > 25 but NOT Caucasian Males enrolled in at CCM')
